# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.2046, 0.7582, 0.1224],
#         [0.8290, 0.1991, 0.6317],
#         [0.8875, 0.3367, 0.0339],
#         [0.1814, 0.1877, 0.1712],
#         [0.6035, 0.5379, 0.5897]])
